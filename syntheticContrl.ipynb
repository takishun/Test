# %%
#Import packages
import pandas as pd
import numpy as np

from SyntheticControlMethods import Synth, DiffSynth

# %%
# Data Requirements
#Import German Reunification data from paper
#Can be found in /datasets folder in repo
data = pd.read_csv("german_reunification.csv")
data = data.drop(columns="code", axis=1)
data.head()
# Out:
#   country  year   gdp   infrate     trade  schooling  invest60  invest70  \
# 0     USA  1960  2879       NaN  9.693181  43.799999       NaN       NaN
# 1     USA  1961  2929  1.075182  9.444655        NaN       NaN       NaN
# 2     USA  1962  3103  1.116071  9.429324        NaN       NaN       NaN
# 3     USA  1963  3227  1.214128  9.470706        NaN       NaN       NaN
# 4     USA  1964  3420  1.308615  9.725879        NaN       NaN       NaN
#
#    invest80  industry
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN

# %%
#Fit synthetic control
sc = Synth(data, "gdp", "country", "year", 1990, "West Germany", n_optim=100)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.58778D+07    |proj g|=  8.75000D-01
#
# At iterate    3    f=  3.17882D+05    |proj g|=  8.75842D-01
#
# At iterate    6    f=  2.77883D+05    |proj g|=  8.74216D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8      6     12     13     0     0   8.742D-01   2.779D+05
#   F =   277883.14210549375
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 #Fit synthetic control
# ----> 2 sc = Synth(data, "gdp", "country", "year", 1990, "West Germany", n_optim=100)
#
# File /opt/anaconda3/envs/prtenv/lib/python3.9/site-packages/SyntheticControlMethods/main.py:340, in Synth.__init__(self, dataset, outcome_var, id_var, time_var, treatment_period, treated_unit, n_optim, pen, exclude_columns, random_seed, **kwargs)
#     337 self.original_data = SynthBase(**original_checked_input)
#     339 #Get synthetic Control
# --> 340 self.optimize(self.original_data.treated_outcome, self.original_data.treated_covariates,
#     341             self.original_data.control_outcome, self.original_data.control_covariates,
#     342             self.original_data.pairwise_difference,
#     343             self.original_data, False, pen, n_optim)
#     345 #Compute rmspe_df
#     346 self._pre_post_rmspe_ratios(None, False)
#
# File /opt/anaconda3/envs/prtenv/lib/python3.9/site-packages/SyntheticControlMethods/optimize.py:103, in Optimize.optimize(self, treated_outcome, treated_covariates, control_outcome, control_covariates, pairwise_difference, data, placebo, pen, steps, verbose)
#     100     bnds = tuple((0,20) if ((pen=="auto") and (x==data.n_covariates)) else (0,1) for x in range(data.n_covariates + 1))
#     102 #Optimze
# --> 103 res = minimize(self.total_loss, v_0,  args=(args),
#     104                 method='L-BFGS-B', bounds=bnds,
#     105                 options={'gtol': 1e-8,'disp':3, 'iprint':3})
#     107 if verbose:
#     108     print("Successful:", res.success)
#
# File /opt/anaconda3/envs/prtenv/lib/python3.9/site-packages/scipy/optimize/_minimize.py:535, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     532 x0 = np.atleast_1d(np.asarray(x0))
#     534 if x0.ndim != 1:
# --> 535     raise ValueError("'x0' must only have one dimension.")
#     537 if x0.dtype.kind in np.typecodes["AllInteger"]:
#     538     x0 = np.asarray(x0, dtype=float)
#
# ValueError: 'x0' must only have one dimension.
